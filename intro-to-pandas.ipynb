# %%
import pandas as pd

# %% [markdown]
# ### There is 2 main data types

# %% [markdown]
# #### 1. Series (1-dimensional)

# %%
series = pd.Series(["BMW", "MB", "Toyota", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1        MB
# 2    Toyota
# 3     Honda
# dtype: object

# %%
colors = pd.Series(["red", "blue", "white", "black"])

# %%
colors
# Out:
# 0      red
# 1     blue
# 2    white
# 3    black
# dtype: object

# %%
prices = pd.Series(["20000", "45000", "15000", "18000"])

# %% [markdown]
# #### 2. Dataframes (2-dimensional)

# %%
car_data = pd.DataFrame({"Car make": series, "Color": colors, "Price": prices})

# %%
car_data
# Out:
#   Car make  Color  Price
# 0      BMW    red  20000
# 1       MB   blue  45000
# 2   Toyota  white  15000
# 3    Honda  black  18000

# %% [markdown]
# ## Import Data

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Exporting a dataframe

# %%
car_sales.to_csv("exported-car-salex.csv", index=False)

# %%
exported_car_sales = pd.read_csv("exported-car-salex.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe Data

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %% [markdown]
# ## Viewing and selecting data

# %%
car_sales.head(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %% [markdown]
# ### .loc & .iloc

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Make"] == "Honda"]
# Out:
#     Make Colour  Odometer (KM)  Doors      Price
# 1  Honda    Red          87899      4  $5,000.00
# 6  Honda   Blue          45698      4  $7,500.00
# 7  Honda   Blue          54738      4  $7,000.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
pd.crosstab(car_sales["Doors"], car_sales["Make"])
# Out:
# Make   BMW  Honda  Nissan  Toyota
# Doors
# 3        0      0       0       1
# 4        0      3       2       3
# 5        1      0       0       0

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales['Price'].str.replace('[\$\,\.]', '', regex=True).astype(int)

# %%
car_sales["Price"]
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: int32

# %%
car_sales["Price"] = car_sales["Price"].div(100)

# %%
car_sales["Price"] = car_sales["Price"].astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales.to_csv('price-to-int.csv')

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
car_sales["Colour"] = car_sales["Colour"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  white         150043      4   4000
# 1   honda    red          87899      4   5000
# 2  toyota   blue          32549      3   7000
# 3     bmw  black          11179      5  22000
# 4  nissan  white         213095      4   3500
# 5  toyota  green          99213      4   4500
# 6   honda   blue          45698      4   7500
# 7   honda   blue          54738      4   7000
# 8  toyota  white          60000      4   6250
# 9  nissan  white          31600      4   9700

# %%
cs_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
cs_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
cs_missing["Odometer"] = cs_missing["Odometer"].fillna(cs_missing["Odometer"].mean()).astype(int)

# %%
cs_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White    150043    4.0   $4,000
# 1   Honda    Red     87899    4.0   $5,000
# 2  Toyota   Blue     92302    3.0   $7,000
# 3     BMW  Black     11179    5.0  $22,000
# 4  Nissan  White    213095    4.0   $3,500
# 5  Toyota  Green     92302    4.0   $4,500

# %%
cs_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
cs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 cs
#
# NameError: name 'cs' is not defined

# %%
cs_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
cs_missing_dropped = cs_missing.dropna()

# %%
cs_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
cs_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  white         150043      4   4000
# 1   honda    red          87899      4   5000
# 2  toyota   blue          32549      3   7000
# 3     bmw  black          11179      5  22000
# 4  nissan  white         213095      4   3500
# 5  toyota  green          99213      4   4500
# 6   honda   blue          45698      4   7500
# 7   honda   blue          54738      4   7000
# 8  toyota  white          60000      4   6250
# 9  nissan  white          31600      4   9700

# %% [markdown]
# ## Column from series

# %%
seats_column = pd.Series([5,5,5,5,5])

# %%
car_sales["Seats"] = seats_column

# %%
car_sales["Seats"] = car_sales["Seats"].fillna(car_sales["Seats"].mean()).astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  toyota  white         150043      4   4000      5
# 1   honda    red          87899      4   5000      5
# 2  toyota   blue          32549      3   7000      5
# 3     bmw  black          11179      5  22000      5
# 4  nissan  white         213095      4   3500      5
# 5  toyota  green          99213      4   4500      5
# 6   honda   blue          45698      4   7500      5
# 7   honda   blue          54738      4   7000      5
# 8  toyota  white          60000      4   6250      5
# 9  nissan  white          31600      4   9700      5

# %% [markdown]
# ## Column from pythin list

# %%
fuel_economy = [5.6, 7.9, 1.3, 4.5, 6.2, 4.5, 6.7, 9.5, 10.4, 11.3]
car_sales["Fuel per 100KM"] = fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM
# 0  toyota  white         150043      4   4000      5             5.6
# 1   honda    red          87899      4   5000      5             7.9
# 2  toyota   blue          32549      3   7000      5             1.3
# 3     bmw  black          11179      5  22000      5             4.5
# 4  nissan  white         213095      4   3500      5             6.2
# 5  toyota  green          99213      4   4500      5             4.5
# 6   honda   blue          45698      4   7500      5             6.7
# 7   honda   blue          54738      4   7000      5             9.5
# 8  toyota  white          60000      4   6250      5            10.4
# 9  nissan  white          31600      4   9700      5            11.3

# %%
car_sales["Total fuel used(L)"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  white         150043      4   4000      5             5.6
# 1   honda    red          87899      4   5000      5             7.9
# 2  toyota   blue          32549      3   7000      5             1.3
# 3     bmw  black          11179      5  22000      5             4.5
# 4  nissan  white         213095      4   3500      5             6.2
# 5  toyota  green          99213      4   4500      5             4.5
# 6   honda   blue          45698      4   7500      5             6.7
# 7   honda   blue          54738      4   7000      5             9.5
# 8  toyota  white          60000      4   6250      5            10.4
# 9  nissan  white          31600      4   9700      5            11.3
#
#    Total fuel used(L)
# 0            8402.408
# 1            6944.021
# 2             423.137
# 3             503.055
# 4           13211.890
# 5            4464.585
# 6            3061.766
# ...

# %% [markdown]
# ## Create a column from a asingle value

# %%
car_sales["Number of wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  white         150043      4   4000      5             5.6
# 1   honda    red          87899      4   5000      5             7.9
# 2  toyota   blue          32549      3   7000      5             1.3
# 3     bmw  black          11179      5  22000      5             4.5
# 4  nissan  white         213095      4   3500      5             6.2
# 5  toyota  green          99213      4   4500      5             4.5
# 6   honda   blue          45698      4   7500      5             6.7
# 7   honda   blue          54738      4   7000      5             9.5
# 8  toyota  white          60000      4   6250      5            10.4
# 9  nissan  white          31600      4   9700      5            11.3
#
#    Total fuel used(L)  Number of wheels
# 0            8402.408                 4
# 1            6944.021                 4
# 2             423.137                 4
# 3             503.055                 4
# ...

# %%
car_sales.to_csv("reach-car-sales.csv")
