# %%
import pandas as pd

# %%
car_sales = pd.read_csv("reach-car-sales.csv")

# %%
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price  Seats  \
# 0           0  toyota  white         150043      4   4000      5
# 1           1   honda    red          87899      4   5000      5
# 2           2  toyota   blue          32549      3   7000      5
# 3           3     bmw  black          11179      5  22000      5
# 4           4  nissan  white         213095      4   3500      5
# 5           5  toyota  green          99213      4   4500      5
# 6           6   honda   blue          45698      4   7500      5
# 7           7   honda   blue          54738      4   7000      5
# 8           8  toyota  white          60000      4   6250      5
# 9           9  nissan  white          31600      4   9700      5
#
#    Fuel per 100KM  Total fuel used(L)  Number of wheels
# 0             5.6            8402.408                 4
# 1             7.9            6944.021                 4
# 2             1.3             423.137                 4
# ...

# %%
car_sales.drop("Unnamed: 0", axis=1, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  white         150043      4   4000      5             5.6
# 1   honda    red          87899      4   5000      5             7.9
# 2  toyota   blue          32549      3   7000      5             1.3
# 3     bmw  black          11179      5  22000      5             4.5
# 4  nissan  white         213095      4   3500      5             6.2
# 5  toyota  green          99213      4   4500      5             4.5
# 6   honda   blue          45698      4   7500      5             6.7
# 7   honda   blue          54738      4   7000      5             9.5
# 8  toyota  white          60000      4   6250      5            10.4
# 9  nissan  white          31600      4   9700      5            11.3
#
#    Total fuel used(L)  Number of wheels
# 0            8402.408                 4
# 1            6944.021                 4
# 2             423.137                 4
# 3             503.055                 4
# ...

# %%
car_sales = car_sales.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  white         150043      4   4000      5             5.6
# 2  toyota   blue          32549      3   7000      5             1.3
# 4  nissan  white         213095      4   3500      5             6.2
# 7   honda   blue          54738      4   7000      5             9.5
# 6   honda   blue          45698      4   7500      5             6.7
# 1   honda    red          87899      4   5000      5             7.9
# 3     bmw  black          11179      5  22000      5             4.5
# 9  nissan  white          31600      4   9700      5            11.3
# 5  toyota  green          99213      4   4500      5             4.5
# 8  toyota  white          60000      4   6250      5            10.4
#
#    Total fuel used(L)  Number of wheels
# 0            8402.408                 4
# 2             423.137                 4
# 4           13211.890                 4
# 7            5200.110                 4
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  white         150043      4   4000      5             5.6
# 2  toyota   blue          32549      3   7000      5             1.3
# 4  nissan  white         213095      4   3500      5             6.2
# 7   honda   blue          54738      4   7000      5             9.5
# 6   honda   blue          45698      4   7500      5             6.7
# 1   honda    red          87899      4   5000      5             7.9
# 3     bmw  black          11179      5  22000      5             4.5
# 9  nissan  white          31600      4   9700      5            11.3
# 5  toyota  green          99213      4   4500      5             4.5
# 8  toyota  white          60000      4   6250      5            10.4
#
#    Total fuel used(L)  Number of wheels
# 0            8402.408                 4
# 2             423.137                 4
# 4           13211.890                 4
# 7            5200.110                 4
# ...

# %%
car_sales = car_sales.drop("level_0", axis=1)

# %%
car_sales
# Out:
#    index    Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0      0  toyota  white         150043      4   4000      5             5.6
# 1      2  toyota   blue          32549      3   7000      5             1.3
# 2      4  nissan  white         213095      4   3500      5             6.2
# 3      7   honda   blue          54738      4   7000      5             9.5
# 4      6   honda   blue          45698      4   7500      5             6.7
# 5      1   honda    red          87899      4   5000      5             7.9
# 6      3     bmw  black          11179      5  22000      5             4.5
# 7      9  nissan  white          31600      4   9700      5            11.3
# 8      5  toyota  green          99213      4   4500      5             4.5
# 9      8  toyota  white          60000      4   6250      5            10.4
#
#    Total fuel used(L)  Number of wheels
# 0            8402.408                 4
# 1             423.137                 4
# ...

# %%
car_sales = car_sales.drop("index", axis=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  white         150043      4   4000      5             5.6
# 1  toyota   blue          32549      3   7000      5             1.3
# 2  nissan  white         213095      4   3500      5             6.2
# 3   honda   blue          54738      4   7000      5             9.5
# 4   honda   blue          45698      4   7500      5             6.7
# 5   honda    red          87899      4   5000      5             7.9
# 6     bmw  black          11179      5  22000      5             4.5
# 7  nissan  white          31600      4   9700      5            11.3
# 8  toyota  green          99213      4   4500      5             4.5
# 9  toyota  white          60000      4   6250      5            10.4
#
#    Total fuel used(L)  Number of wheels
# 0            8402.408                 4
# 1             423.137                 4
# 2           13211.890                 4
# 3            5200.110                 4
# ...
